# %% [markdown]
# <a href="https://colab.research.google.com/github/Monisha1205/google_colab_quanqual/blob/main/Chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-18d036a6-db6c-4091-8df4-3cd307faa28a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-18d036a6-db6c-4091-8df4-3cd307faa28a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataset=pd.read_csv("/content/pre_dataset.csv")
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.columns
# Out:
# Index(['gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s', 'degree_p',
#        'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p', 'status',
#        'salary'],
#       dtype='object')

# %%
plt.bar(dataset["gender"],dataset["ssc_p"])
plt.show()

# %%
plt.plot(dataset["hsc_p"],marker = 'o')
plt.show()

# %%
plt.scatter(dataset["mba_p"],dataset["hsc_p"])
plt.show()

# %%
plt.hist(dataset["hsc_p"])
plt.show()

# %%
plt.pie(dataset["status"].value_counts(),labels = dataset["status"].unique())
plt.show()

# %%
plt.boxplot(dataset["hsc_p"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x79b9542ea710>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x79b9542ea990>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x79b9542ea5d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x79b9542eac10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x79b9542ead50>],
#  'means': []}

# %%
def quanqual(dataset):
  quan = []
  qual = []
  for ch in  dataset.columns:
    if dataset[ch].dtype == "O":
      #print("qual")
      qual.append(ch)
    else:
      #print("quan")
      quan.append(ch)
  return quan,qual
quan,qual = quanqual(dataset)

# %%
quan
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
dataset[quan]
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0    67.00  91.00     58.00     55.0  58.80       0.0
# 1    79.33  78.33     77.48     86.5  66.28       0.0
# 2    65.00  68.00     64.00     75.0  57.80       0.0
# 3    56.00  52.00     52.00     66.0  59.43       0.0
# 4    85.80  73.60     73.30     96.8  55.50       0.0
# ..     ...    ...       ...      ...    ...       ...
# 210  80.60  82.00     77.60     91.0  74.49  500000.0
# 211  58.00  60.00     72.00     74.0  53.62  500000.0
# 212  67.00  67.00     73.00     59.0  69.72  650000.0
# 213  74.00  66.00     58.00     70.0  60.23  690000.0
# 214  62.00  58.00     53.00     89.0  60.22  706250.0
#
# [215 rows x 6 columns]

# %%
corr_of = dataset[quan].corr()

# %%
corr_of
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.513478  0.538686  0.261993  0.388478 -0.061355
# hsc_p     0.513478  1.000000  0.434606  0.240775  0.348452 -0.045025
# degree_p  0.538686  0.434606  1.000000  0.227147  0.402376 -0.064261
# etest_p   0.261993  0.240775  0.227147  1.000000  0.218055  0.104590
# mba_p     0.388478  0.348452  0.402376  0.218055  1.000000  0.041195
# salary   -0.061355 -0.045025 -0.064261  0.104590  0.041195  1.000000

# %%
plt.imshow(corr_of)
plt.colorbar()
plt.show()

# %%
plt.barh(dataset["gender"],dataset["ssc_p"])
plt.show()

# %%
plt.fill_between(
    dataset.index,
    dataset["degree_p"],
    dataset["mba_p"],
    alpha=0.3
)

plt.show()
