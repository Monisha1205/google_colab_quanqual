# %% [markdown]
# <a href="https://colab.research.google.com/github/Monisha1205/google_colab_quanqual/blob/main/ASSESSMENT_PRACTICAL_DATA_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  # 3. practical tasks
#  # A. identify data types
#
#  # 1. Classify each column as Qualitative (Categorical) or Quantitative (Numerical).

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a50c0594-7c4f-4470-99c9-239de0fe68cf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a50c0594-7c4f-4470-99c9-239de0fe68cf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataset = pd.read_csv("/content/Online_Store_Orders.csv")

# %%
dataset.head()
# Out:
#    Order_ID Customer        City  Age Product_Category  Order_Value  Quantity  \
# 0      1001     Arun     Chennai   22      Electronics         2450         2
# 1      1002    Priya     Madurai   29         Clothing         1800         3
# 2      1003    Rahul     Chennai   35      Electronics         5200         1
# 3      1004    Divya  Coimbatore   24           Beauty         1250         2
# 4      1005  Karthik      Trichy   41             Home         3100         4
#
#    Delivery_Days  Rating
# 0              3       4
# 1              5       4
# 2              4       5
# 3              6       3
# 4              3       4

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          40 non-null     int64
#  1   Customer          40 non-null     object
#  2   City              40 non-null     object
#  3   Age               40 non-null     int64
#  4   Product_Category  40 non-null     object
#  5   Order_Value       40 non-null     int64
#  6   Quantity          40 non-null     int64
#  7   Delivery_Days     40 non-null     int64
#  8   Rating            40 non-null     int64
# dtypes: int64(6), object(3)
# memory usage: 2.9+ KB

# %%
def quanqual(dataset):
  quan = []
  qual = []
  for ch in  dataset.columns:
    if dataset[ch].dtype == "O":
      #print("qual")
      qual.append(ch)
    else:
      #print("quan")
      quan.append(ch)
  return quan,qual

# %%
quan, qual = quanqual(dataset)

# %% [markdown]
# # Answer

# %%
quan # Quantitative (Numerical)
# Out:
# ['Order_ID', 'Age', 'Order_Value', 'Quantity', 'Delivery_Days', 'Rating']

# %%
qual  # Qualitative (Categorical)
# Out:
# ['Customer', 'City', 'Product_Category']

# %% [markdown]
# # 2 . Among the quantitative columns, identify which are Discrete and which are Continuous, where appropriate.

# %% [markdown]
# **Answer**

# %%
# Order_ID , Order value , Quantity , Delivery_Days , Rating - Discrete
# Age - Continuous

# %% [markdown]
# # 3. Identify at least one nominal categorical variable and explain why.

# %% [markdown]
# **Answer**

# %%
dataset["City"].unique() # city - 'Chennai', 'Madurai', 'Coimbatore', 'Trichy'
# Out:
# array(['Chennai', 'Madurai', 'Coimbatore', 'Trichy'], dtype=object)

# %%
dataset["Product_Category"].unique()# product category - 'Electronics', 'Clothing', 'Beauty', 'Home'
# Out:
# array(['Electronics', 'Clothing', 'Beauty', 'Home'], dtype=object)

# %%
# Nominal categorical
'''  1. Categories cannot be sorted from low to high or best to worst.
     2. Each item fits into only one category.
     3. Nominal data is a type of categorical data that labels or sorts
      items into distinct, non-overlapping groups without any natural order, rank, or numerical value '''
''' We cannot be sorted from low to high in the given dataset have city and product category that why
 this is comes under nominal dataset'''
# Out:
# ' We cannot be sorted from low to high in the given dataset have city and product category that why\n this is comes under nominal dataset'

# %% [markdown]
# # B. Frequency Analysis

# %% [markdown]
# # 4. Create a frequency table for Product_Category showing Category, Frequency, and Percentage.

# %% [markdown]
# **Answer**

# %%
qual
# Out:
# ['Customer', 'City', 'Product_Category']

# %%
dataset[qual[2]].unique()
# Out:
# array(['Electronics', 'Clothing', 'Beauty', 'Home'], dtype=object)

# %%
dataset[qual[2]].value_counts()
# Out:
# Product_Category
# Electronics    11
# Clothing       10
# Home           10
# Beauty          9
# Name: count, dtype: int64

# %%
dataset.shape[0]
# Out:
# 40

# %%
Freq_table = pd.DataFrame(columns=("unique_Category", "frequency", "relative_frequency", "cumsum"))
Freq_table["unique_Category"] = dataset["Product_Category"].unique()
Freq_table["frequency"] = dataset["Product_Category"].value_counts().values
Freq_table["relative_frequency"] = (Freq_table["frequency"]/dataset.shape[0])* 100
Freq_table["cumsum"] = Freq_table["relative_frequency"].cumsum()

# %%
Freq_table
# Out:
#   unique_Category  frequency  relative_frequency  cumsum
# 0     Electronics         11                27.5    27.5
# 1        Clothing         10                25.0    52.5
# 2          Beauty         10                25.0    77.5
# 3            Home          9                22.5   100.0

# %% [markdown]
# # 5. Create a frequency table for City showing Frequency and Percentage.

# %% [markdown]
# **Answer**

# %%
for ColumnsName in qual:
  Freq_table = pd.DataFrame(columns=("unique_Category", "frequency", "relative_frequency", "cumsum"))
  Freq_table["unique_Category"] = dataset[ColumnsName].unique()
  Freq_table["frequency"] = dataset[ColumnsName].value_counts().values
  Freq_table["relative_frequency"] = (Freq_table["frequency"]/dataset.shape[0])* 100
  Freq_table["cumsum"] = Freq_table["relative_frequency"].cumsum()
  print("\nFrequency Table for:", ColumnsName)
  print(Freq_table)
# Out:
# Frequency Table for: Customer
#   unique_Category  frequency  relative_frequency  cumsum
# 0            Arun          4                10.0    10.0
# 1           Priya          4                10.0    20.0
# 2           Rahul          4                10.0    30.0
# 3           Divya          4                10.0    40.0
# 4         Karthik          4                10.0    50.0
# 5           Meena          4                10.0    60.0
# 6          Sanjay          4                10.0    70.0
# 7           Aisha          4                10.0    80.0
# 8           Vijay          4                10.0    90.0
# 9           Nisha          4                10.0   100.0
#
# Frequency Table for: City
#   unique_Category  frequency  relative_frequency  cumsum
# 0         Chennai         12                30.0    30.0
# 1         Madurai         10                25.0    55.0
# 2      Coimbatore          9                22.5    77.5
# ...

# %% [markdown]
# # 6. Find the most frequently occurring Product_Category.

# %% [markdown]
# **answer**

# %%
# The frequency table shows that Electronics products are sold most frequently.

# %% [markdown]
# # 7. Create a frequency table for Rating (1–5).  Which rating occurs most often?

# %% [markdown]
# **Answer**

# %%
for ColumnsName in quan:
  Freq_table = pd.DataFrame(columns=("unique_frequency", "frequency", "relative_frequency", "cumsum"))
  Freq_table["unique_frequency"] = dataset[ColumnsName].unique()
  Freq_table["frequency"] = dataset[ColumnsName].value_counts().values
  Freq_table["relative_frequency"] = (Freq_table["frequency"]/dataset.shape[0])* 100
  Freq_table["cumsum"] = Freq_table["relative_frequency"].cumsum()
  print("\nFrequency Table for:", ColumnsName)
  print(Freq_table)
# Out:
# Frequency Table for: Order_ID
#     unique_frequency  frequency  relative_frequency  cumsum
# 0               1001          1                 2.5     2.5
# 1               1002          1                 2.5     5.0
# 2               1003          1                 2.5     7.5
# 3               1004          1                 2.5    10.0
# 4               1005          1                 2.5    12.5
# 5               1006          1                 2.5    15.0
# 6               1007          1                 2.5    17.5
# 7               1008          1                 2.5    20.0
# 8               1009          1                 2.5    22.5
# 9               1010          1                 2.5    25.0
# 10              1011          1                 2.5    27.5
# 11              1012          1                 2.5    30.0
# 12              1013          1                 2.5    32.5
# 13              1014          1                 2.5    35.0
# ...

# %%
# rating 4 is occurs more often

# %% [markdown]
# # C. Central Tendency

# %% [markdown]
# # 8. For Order_Value, calculate Mean, Median, and Mode.
# # 9. For Age, calculate Mean, Median, and Mode.
# # 10. For Delivery_Days, calculate Mean and Median.

# %%
quan
# Out:
# ['Order_ID', 'Age', 'Order_Value', 'Quantity', 'Delivery_Days', 'Rating']

# %%
descriptive = pd.DataFrame(index = ["Mean", "Median", "Mode"], columns = quan)
for ColumnsName in quan:
  descriptive[ColumnsName]["Mean"] = dataset[ColumnsName].mean()
  descriptive[ColumnsName]["Median"] = dataset[ColumnsName].median()
  descriptive[ColumnsName]["Mode"]= dataset[ColumnsName].mode()[0]
# Out:
# /tmp/ipykernel_2169/1582507035.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[ColumnsName]["Mean"] = dataset[ColumnsName].mean()
# ...

# %% [markdown]
# **Answer**

# %%
descriptive
# Out:
#        Order_ID   Age Order_Value Quantity Delivery_Days Rating
# Mean     1020.5  29.6      2815.0    2.225         4.425  4.025
# Median   1020.5  28.0      2525.0      2.0           4.0    4.0
# Mode       1001    22        2750        2             4      4

# %% [markdown]
# # 11. Compare Mean and Median for Order_Value. Which one better represents a typical order if extreme values are present? Explain briefly.

# %% [markdown]
# **Answer**

# %%
descriptive = pd.DataFrame(index = ["Mean", "Median", "Mode", "Min", "25th", "50th", "75th", "Max", "IQR", "1.5IQR", "LowerOutlier", "GreaterOutlier"], columns = quan)
for ColumnsName in quan:
  descriptive[ColumnsName]["Mean"] = dataset[ColumnsName].mean()
  descriptive[ColumnsName]["Median"] = dataset[ColumnsName].median()
  descriptive[ColumnsName]["Mode"] = dataset[ColumnsName].mode()[0]
  descriptive[ColumnsName]["Min"] = dataset.describe()[ColumnsName]["min"]
  descriptive[ColumnsName]["25th"] = dataset.describe()[ColumnsName]["25%"]
  descriptive[ColumnsName]["50th"] = dataset.describe()[ColumnsName]["50%"]
  descriptive[ColumnsName]["75th"] = dataset.describe()[ColumnsName]["75%"]
  descriptive[ColumnsName]["Max"] = dataset.describe()[ColumnsName]["max"]
  descriptive[ColumnsName]["IQR"] = descriptive[ColumnsName]["75th"] - descriptive[ColumnsName]["25th"]
  descriptive[ColumnsName]["1.5IQR"] = 1.5 * descriptive[ColumnsName]["IQR"]
  descriptive[ColumnsName]["LowerOutlier"] = descriptive[ColumnsName]["25th"] - descriptive[ColumnsName]["1.5IQR"]
  descriptive[ColumnsName]["GreaterOutlier"] = descriptive[ColumnsName]["75th"] + descriptive[ColumnsName]["1.5IQR"]
# Out:
# /tmp/ipykernel_2169/3316622404.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[ColumnsName]["Mean"] = dataset[ColumnsName].mean()
# ...

# %%
descriptive
# Out:
#                Order_ID   Age Order_Value Quantity Delivery_Days Rating
# Mean             1020.5  29.6      2815.0    2.225         4.425  4.025
# Median           1020.5  28.0      2525.0      2.0           4.0    4.0
# Mode               1001    22        2750        2             4      4
# Min              1001.0  22.0       950.0      1.0           2.0    3.0
# 25th            1010.75  24.0      1725.0     1.75           3.0   3.75
# 50th             1020.5  28.0      2525.0      2.0           4.0    4.0
# 75th            1030.25  35.0      3325.0      3.0          5.25    5.0
# Max              1040.0  41.0      6800.0      5.0           7.0    5.0
# IQR                19.5  11.0      1600.0     1.25          2.25   1.25
# 1.5IQR            29.25  16.5      2400.0    1.875         3.375  1.875
# LowerOutlier      981.5   7.5      -675.0   -0.125        -0.375  1.875
# GreaterOutlier   1059.5  51.5      5725.0    4.875         8.625  6.875

# %%
lesser = []
greater = []
for ColumnsNames in quan:
  if descriptive[ColumnsNames]["Min"] < descriptive[ColumnsNames]["LowerOutlier"]:
    lesser.append(ColumnsNames)
  if descriptive[ColumnsNames]["Max"] > descriptive[ColumnsNames]["GreaterOutlier"]:
    greater.append(ColumnsNames)

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# ['Order_Value', 'Quantity']

# %%
# The mean Order_Value is ₹2815.0, while the median Order_Value is ₹2525.0. Since the mean is much higher than the median, this suggests that some extremely high order values are affecting the mean. Therefore, the median better represents a typical order because it is less affected by extreme values (outliers).

# %% [markdown]
# # D. Percentile Analysis

# %% [markdown]
# # 12. Calculate the 25th percentile (P25) of Order_Value

# %% [markdown]
# **Answer**

# %%
descriptive["Order_Value"]["25th"]
# Out:
# np.float64(1725.0)

# %%
# Based on the calculation performed using the above loop, the 25th percentile value of Order_Value is 1725.0.

# %% [markdown]
# # 13. Calculate the 50th percentile (P50) of Order_Value and compare it with the Median.

# %% [markdown]
# **Answer**

# %%
descriptive["Order_Value"]["50th"]
# Out:
# np.float64(2525.0)

# %%
descriptive["Order_Value"]["Median"]
# Out:
# 2525.0

# %%
# Both P50th and Median are based on the middle position of the data when the values are arranged in ascending order. Therefore, P50th and Median have the same value.

# %% [markdown]
# # 14. Calculate the 75th percentile (P75) of Order_Value.

# %% [markdown]
# **Answer**

# %%
descriptive["Order_Value"]["75th"]
# Out:
# np.float64(3325.0)

# %%
# Based on the calculation performed using the above loop, the 75th percentile value of Order_Value is 3325.

# %% [markdown]
# # 15. Calculate the 90th percentile (P90) of Order_Value.

# %% [markdown]
# **Answer**

# %%
dataset["Order_Value"].quantile(0.90)
# Out:
# np.float64(5110.0)

# %%
# Based on the above Code, the 90th percentile value of Order_Value is 5110.

# %% [markdown]
# # 16. Interpret P75 in one simple business sentence.

# %% [markdown]
# **Answer**

# %%
descriptive["Order_Value"]["75th"]
# Out:
# np.float64(3325.0)

# %%
descriptive["Order_Value"]["Max"] - descriptive["Order_Value"]["75th"] # remaining 25% above the 75%
# Out:
# np.float64(3475.0)

# %%
# The 75th percentile of Order_Value is ₹3,325, meaning that 75% of orders have an order value of ₹3,325 or less, while 25% of orders have an order value above ₹3,325.

# %% [markdown]
# # E. IQR & Outlier Detection

# %% [markdown]
# # 17. Calculate Q1 and Q3 for Order_Value.

# %% [markdown]
# **Answer**

# %%
# p25th = Q1
# p50th = Q2
# p75th = Q3
# p100th = Q4

# %%
descriptive.iloc[[4,6]]
# Out:
#      Order_ID   Age Order_Value Quantity Delivery_Days Rating
# 25th  1010.75  24.0      1725.0     1.75           3.0   3.75
# 75th  1030.25  35.0      3325.0      3.0          5.25    5.0

# %%
# Based on the calculation performed using the above loop, the IQR value of Order_Value is 1600.

# %% [markdown]
# # 18. Calculate IQR = Q3 − Q1.

# %%
display(descriptive.iloc[[8]]) # Interquertile range = Q3 - Q1
# Out:
#     Order_ID   Age Order_Value Quantity Delivery_Days Rating
# IQR     19.5  11.0      1600.0     1.25          2.25   1.25

# %% [markdown]
# #19. Calculate the Lower Bound and Upper Bound using the 1.5 × IQR rule.

# %% [markdown]
# **Answer**

# %%
display(descriptive.iloc[[9]])
# Out:
#        Order_ID   Age Order_Value Quantity Delivery_Days Rating
# 1.5IQR    29.25  16.5      2400.0    1.875         3.375  1.875

# %% [markdown]
# # 20 .Identify all Order_Value records that are potential outliers.

# %% [markdown]
# **Answer**

# %%
greater
# Out:
# ['Order_Value', 'Quantity']

# %%
# from the above mentioned Order value and Quantity as greater outliers in this dataset, lower outliers not present.

# %% [markdown]
# # 21. Repeat the IQR analysis for Delivery_Days.

# %% [markdown]
# **Answer**

# %%
descriptive["Delivery_Days"]["IQR"] # IQR analysis for Delivery_Days is 2.25
# Out:
# np.float64(2.25)

# %%
descriptive["Delivery_Days"]["1.5IQR"] # 1.5IQR analysis for Delivery_Days is 3.375
# Out:
# np.float64(3.375)

# %% [markdown]
# # 22. Write one sentence explaining what an outlier means in this dataset.

# %% [markdown]
# **Answer**

# %%
# An outlier is an Order_Value that is unusually high or low compared with most of the other orders in the dataset.

# %% [markdown]
# # F. Business Interpretation

# %%
for ColumnsName in quan:
  Freq_table = pd.DataFrame(columns=("unique_values", "frequency", "relative_frequency", "cumsum"))
  Freq_table["unique_values"] = dataset[ColumnsName].value_counts().sort_index().index
  Freq_table["frequency"] = dataset[ColumnsName].value_counts().sort_index().values
  Freq_table["relative_frequency"] = Freq_table["frequency"]/dataset.shape[0]
  Freq_table["cumsum"] = round((Freq_table["relative_frequency"].cumsum())*100,2)
  print("\nFrequency Table for:", ColumnsName)
  print(Freq_table)
# Out:
# Frequency Table for: Order_ID
#     unique_values  frequency  relative_frequency  cumsum
# 0            1001          1               0.025     2.5
# 1            1002          1               0.025     5.0
# 2            1003          1               0.025     7.5
# 3            1004          1               0.025    10.0
# 4            1005          1               0.025    12.5
# 5            1006          1               0.025    15.0
# 6            1007          1               0.025    17.5
# 7            1008          1               0.025    20.0
# 8            1009          1               0.025    22.5
# 9            1010          1               0.025    25.0
# 10           1011          1               0.025    27.5
# 11           1012          1               0.025    30.0
# 12           1013          1               0.025    32.5
# 13           1014          1               0.025    35.0
# 14           1015          1               0.025    37.5
# ...

# %%
for ColumnsName in qual:
  Freq_table = pd.DataFrame(columns=("unique_values", "frequency", "relative_frequency", "cumsum"))
  Freq_table["unique_values"] = dataset[ColumnsName].value_counts().sort_index().index
  Freq_table["frequency"] = dataset[ColumnsName].value_counts().sort_index().values
  Freq_table["relative_frequency"] = Freq_table["frequency"]/dataset.shape[0]
  Freq_table["cumsum"] = round((Freq_table["relative_frequency"].cumsum())*100,2)
  print("\nFrequency Table for:", ColumnsName)
  print(Freq_table)
# Out:
# Frequency Table for: Customer
#   unique_values  frequency  relative_frequency  cumsum
# 0         Aisha          4                 0.1    10.0
# 1          Arun          4                 0.1    20.0
# 2         Divya          4                 0.1    30.0
# 3       Karthik          4                 0.1    40.0
# 4         Meena          4                 0.1    50.0
# 5         Nisha          4                 0.1    60.0
# 6         Priya          4                 0.1    70.0
# 7         Rahul          4                 0.1    80.0
# 8        Sanjay          4                 0.1    90.0
# 9         Vijay          4                 0.1   100.0
#
# Frequency Table for: City
#   unique_values  frequency  relative_frequency  cumsum
# 0       Chennai         12               0.300    30.0
# 1    Coimbatore          9               0.225    52.5
# 2       Madurai         10               0.250    77.5
# 3        Trichy          9               0.225   100.0
#
# ...

# %% [markdown]
# # 23. Which city appears to have the strongest order activity? Support your answer using frequency.

# %% [markdown]
# **Answer**

# %%
dataset["City"].value_counts()
# Out:
# City
# Chennai       12
# Madurai       10
# Coimbatore     9
# Trichy         9
# Name: count, dtype: int64

# %%
# Chennai as higher order compare to other citys

# %% [markdown]
# #24. Which product category appears most popular?

# %% [markdown]
# **Answer**

# %%
dataset["Product_Category"].value_counts()
# Out:
# Product_Category
# Electronics    11
# Clothing       10
# Home           10
# Beauty          9
# Name: count, dtype: int64

# %%
# Electronics items are most popular

# %% [markdown]
# # 25. Based on mean and median Order_Value, describe the typical customer order.

# %% [markdown]
# **Answer**

# %%
mean = dataset["Order_Value"].mean()
median = dataset["Order_Value"].median()

# %%
mean
# Out:
# np.float64(2815.0)

# %%
median
# Out:
# 2525.0

# %%
# Mean(2815.0) > Median(2815.0) Some high value orders may be pulling the mean upward.
'''So, median is often a better description of the typical customer order when there are extreme values.'''
'''Mean = Median → Typical order is around that value.
Mean > Median → Some high-value orders may be pulling the mean upward.
Mean < Median → Some low-value orders may be pulling the mean downward.'''

# %% [markdown]
# # 26. Write 3 short insights that a manager could understand from your analysis.

# %% [markdown]
# **Answer**

# %%
''' 1. City Insight:

Chennai has the strongest order activity with 12 orders (30%), followed by Madurai with 10 orders (25%).

2. Product Category Insight"

Electronics is the most popular product category with 11 orders (27.5%), indicating the highest demand among the four categories.

3. Customer & Order Insight"

The typical order value is ₹2,525 based on the median, while the mean of ₹2,815 suggests that some higher-value orders are increasing the average.'''
