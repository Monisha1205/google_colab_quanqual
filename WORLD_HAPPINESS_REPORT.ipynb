# %% [markdown]
# <a href="https://colab.research.google.com/github/Monisha1205/google_colab_quanqual/blob/main/WORLD_HAPPINESS_REPORT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # import pandas library

# %%
from google.colab import files
uploaded = files.upload() # upload csv dataset from the local drive
# Out:
#      <input type="file" id="files-25306d79-a19c-42a8-923d-3b55fef8cfde" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-25306d79-a19c-42a8-923d-3b55fef8cfde">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataset15=pd.read_csv("/content/2015.csv")
dataset16=pd.read_csv("/content/2016.csv")
dataset17=pd.read_csv("/content/2017.csv")
dataset18=pd.read_csv("/content/2018.csv")
dataset19=pd.read_csv("/content/2019.csv") # read all csv files from the path and asign

# %% [markdown]
# # Q1. Load the available yearly datasets and identify countries, years, columns, missing values, and countries appearing across multiple years.

# %%
dataset15.head() # loading dataset and head of the dataset
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
dataset16.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
dataset17.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
dataset18.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
dataset19.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# # columns

# %%
dataset15.columns # each columns from dataset
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
dataset16.columns # each columns from dataset
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
dataset17.columns # each columns from dataset
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
dataset18.columns # each columns from dataset
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
dataset19.columns # each columns from dataset
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
co_15 = dataset15["Country"].unique() # unique country of the dataset

# %%
reg_15 = dataset15["Region"].unique() # unique country of the dataset

# %%
co_16 = dataset16["Country"].unique()# unique country of the dataset

# %%
reg_16 = dataset16["Region"].unique()# unique country of the dataset

# %%
co_17 = dataset17["Country"].unique()# unique country of the dataset

# %%
co_18 = dataset18["Country or region"].unique() # unique country of the dataset

# %%
co_19 = dataset19["Country or region"].unique() # unique country of the dataset

# %%
all_countries = pd.concat([
    pd.DataFrame({"Country": dataset15["Country"].unique(), "Year": 2015}),
    pd.DataFrame({"Country": dataset15["Region"].unique(), "Year": 2015}),
    pd.DataFrame({"Country": dataset16["Country"].unique(), "Year": 2016}),
    pd.DataFrame({"Country": dataset16["Region"].unique(), "Year": 2016}),
    pd.DataFrame({"Country": dataset17["Country"].unique(), "Year": 2017}),
    pd.DataFrame({"Country": dataset18["Country or region"].unique(), "Year": 2018}),
    pd.DataFrame({"Country": dataset19["Country or region"].unique(), "Year": 2019})
]) # dictionary of the all countries and dataframe

# %%
all_countries
# Out:
#                       Country  Year
# 0                 Switzerland  2015
# 1                     Iceland  2015
# 2                     Denmark  2015
# 3                      Norway  2015
# 4                      Canada  2015
# ..                        ...   ...
# 151                    Rwanda  2019
# 152                  Tanzania  2019
# 153               Afghanistan  2019
# 154  Central African Republic  2019
# 155               South Sudan  2019
#
# [802 rows x 2 columns]

# %%
country_count = all_countries.groupby("Country")["Year"].nunique()
multiple_year_countries = country_count[country_count > 1] # more than one country count

# %%
country_count
# Out:
# Country
# Afghanistan       5
# Albania           5
# Algeria           5
# Angola            4
# Argentina         5
#                  ..
# Vietnam           5
# Western Europe    2
# Yemen             5
# Zambia            5
# Zimbabwe          5
# Name: Year, Length: 180, dtype: int64

# %% [markdown]
# #countries appearing across multiple years

# %%
multiple_year_countries.index.tolist() # muilt years appearing countries
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Australia and New Zealand',
#  'Austria',
#  'Azerbaijan',
#  'Bahrain',
#  'Bangladesh',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Central African Republic',
#  'Central and Eastern Europe',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo (Brazzaville)',
#  'Congo (Kinshasa)',
#  'Costa Rica',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Dominican Republic',
#  'Eastern Asia',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Estonia',
#  'Ethiopia',
#  'Finland',
#  'France',
#  'Gabon',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Guatemala',
#  'Guinea',
#  'Haiti',
#  'Honduras',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
# ...

# %% [markdown]
# # Countries appearing across all 5 years

# %%
exactly_5years =  country_count[country_count == 5] # exactly 5 years

# %%
exactly_5years.index.tolist()
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahrain',
#  'Bangladesh',
#  'Belarus',
#  'Belgium',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo (Brazzaville)',
#  'Congo (Kinshasa)',
#  'Costa Rica',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Estonia',
#  'Ethiopia',
#  'Finland',
#  'France',
#  'Gabon',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Guatemala',
#  'Guinea',
#  'Haiti',
#  'Honduras',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Ivory Coast',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
# ...

# %% [markdown]
# # missing values

# %%
datasets = {
    2015: dataset15,
    2016: dataset16,
    2017: dataset17,
    2018: dataset18,
    2019: dataset19
} # in dictionary format

# %%
for year, data in datasets.items():

    missing = data.isnull().sum()
    missing = missing[missing > 0]

    print(f"\nYear {year}:")
    print(missing)
# Out:
# Year 2015:
# Series([], dtype: int64)
#
# Year 2016:
# Series([], dtype: int64)
#
# Year 2017:
# Series([], dtype: int64)
#
# Year 2018:
# Perceptions of corruption    1
# dtype: int64
#
# Year 2019:
# Series([], dtype: int64)

# %%
dataset18["Perceptions of corruption"] = (
    dataset18["Perceptions of corruption"]
    .fillna(dataset18["Perceptions of corruption"].median())
)

# %%
dataset18.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
dataset15.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
dataset16.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
dataset17.isnull().sum()
# Out:
# Country                          0
# Happiness.Rank                   0
# Happiness.Score                  0
# Whisker.high                     0
# Whisker.low                      0
# Economy..GDP.per.Capita.         0
# Family                           0
# Health..Life.Expectancy.         0
# Freedom                          0
# Generosity                       0
# Trust..Government.Corruption.    0
# Dystopia.Residual                0
# dtype: int64

# %%
dataset19.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %% [markdown]
# # 1. The datasets were checked for missing values. Only one missing value was identified in the 2018 Perceptions of Corruption variable. The missing value was replaced using the median of the column to avoid losing the corresponding country's data.
# # 2. Renamed columns into a common format so the datasets could be compared.
# # 3. In my Find Countries Across Years project, I worked with datasets from multiple years. The main preprocessing was to standardize the column names because the same factors had different names in different years. I created a year-wise column mapping, selected the common factors, renamed them into a consistent format, and then combined the datasets based on the Country column. This made it possible to compare the same countries and factors across different years.

# %% [markdown]
# # Q2. For each year, identify the Top 10 happiest and Bottom 10 countries. Create a suitable visualization.

# %%
for year, data in datasets.items():
    print(f"\n{year}")
    print(data.columns.tolist()) # columns name for all the years
# Out:
# 2015
# ['Country', 'Region', 'Happiness Rank', 'Happiness Score', 'Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']
#
# 2016
# ['Country', 'Region', 'Happiness Rank', 'Happiness Score', 'Lower Confidence Interval', 'Upper Confidence Interval', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']
#
# 2017
# ['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high', 'Whisker.low', 'Economy..GDP.per.Capita.', 'Family', 'Health..Life.Expectancy.', 'Freedom', 'Generosity', 'Trust..Government.Corruption.', 'Dystopia.Residual']
#
# 2018
# ['Overall rank', 'Country or region', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']
#
# 2019
# ...

# %%
# 2015
dataset15 = dataset15.rename(columns={
    "Country": "Country",
    "Happiness Rank": "Rank",
    "Happiness Score": "Happiness Score",
    "Economy (GDP per Capita)": "GDP",
    "Family": "Social Support",
    "Health (Life Expectancy)": "Life Expectancy",
    "Freedom": "Freedom",
    "Trust (Government Corruption)": "Corruption Perception",
    "Generosity": "Generosity"
})


# 2016
dataset16 = dataset16.rename(columns={
    "Country": "Country",
    "Happiness Rank": "Rank",
    "Happiness Score": "Happiness Score",
    "Economy (GDP per Capita)": "GDP",
    "Family": "Social Support",
    "Health (Life Expectancy)": "Life Expectancy",
    "Freedom": "Freedom",
    "Trust (Government Corruption)": "Corruption Perception",
    "Generosity": "Generosity"
})


# 2017
dataset17 = dataset17.rename(columns={
    "Country": "Country",
    "Happiness.Rank": "Rank",
    "Happiness.Score": "Happiness Score",
    "Economy..GDP.per.Capita.": "GDP",
    "Family": "Social Support",
    "Health..Life.Expectancy.": "Life Expectancy",
    "Freedom": "Freedom",
    "Trust..Government.Corruption.": "Corruption Perception",
    "Generosity": "Generosity"
})


# 2018
dataset18 = dataset18.rename(columns={
    "Overall rank": "Rank",
    "Country or region": "Country",
    "Score": "Happiness Score",
    "GDP per capita": "GDP",
    "Social support": "Social Support",
    "Healthy life expectancy": "Life Expectancy",
    "Freedom to make life choices": "Freedom",
    "Perceptions of corruption": "Corruption Perception",
    "Generosity": "Generosity"
})


# 2019
dataset19 = dataset19.rename(columns={
    "Overall rank": "Rank",
    "Country or region": "Country",
    "Score": "Happiness Score",
    "GDP per capita": "GDP",
    "Social support": "Social Support",
    "Healthy life expectancy": "Life Expectancy",
    "Freedom to make life choices": "Freedom",
    "Perceptions of corruption": "Corruption Perception",
    "Generosity": "Generosity"
})

# %%
datasets = {
    2015: dataset15,
    2016: dataset16,
    2017: dataset17,
    2018: dataset18,
    2019: dataset19
}

# %%
for year, data in datasets.items():
    print(year)
    print(data.columns.tolist())
    print()
# Out:
# 2015
# ['Country', 'Region', 'Rank', 'Happiness Score', 'Standard Error', 'GDP', 'Social Support', 'Life Expectancy', 'Freedom', 'Corruption Perception', 'Generosity', 'Dystopia Residual']
#
# 2016
# ['Country', 'Region', 'Rank', 'Happiness Score', 'Lower Confidence Interval', 'Upper Confidence Interval', 'GDP', 'Social Support', 'Life Expectancy', 'Freedom', 'Corruption Perception', 'Generosity', 'Dystopia Residual']
#
# 2017
# ['Country', 'Rank', 'Happiness Score', 'Whisker.high', 'Whisker.low', 'GDP', 'Social Support', 'Life Expectancy', 'Freedom', 'Generosity', 'Corruption Perception', 'Dystopia.Residual']
#
# 2018
# ['Rank', 'Country', 'Happiness Score', 'GDP', 'Social Support', 'Life Expectancy', 'Freedom', 'Generosity', 'Corruption Perception']
#
# 2019
# ['Rank', 'Country', 'Happiness Score', 'GDP', 'Social Support', 'Life Expectancy', 'Freedom', 'Generosity', 'Corruption Perception']

# %%
factors = [
    "GDP",
    "Social Support",
    "Life Expectancy",
    "Freedom",
    "Generosity",
    "Corruption Perception"
]

all_correlations = {}

for year, data in datasets.items():

    correlations = data[factors + ["Happiness Score"]].corr()["Happiness Score"]

    all_correlations[year] = correlations[factors]

correlation_df = pd.DataFrame(all_correlations).T

correlation_df
# Out:
#            GDP  Social Support  Life Expectancy   Freedom  Generosity  \
# 2015  0.780966        0.740605         0.724200  0.568211    0.180319
# 2016  0.790322        0.739252         0.765384  0.566827    0.156848
# 2017  0.812469        0.752737         0.781951  0.570137    0.155256
# 2018  0.802124        0.745760         0.775814  0.544280    0.135825
# 2019  0.793883        0.777058         0.779883  0.566742    0.075824
#
#       Corruption Perception
# 2015               0.395199
# 2016               0.402032
# 2017               0.429080
# 2018               0.400596
# 2019               0.385613

# %%
country_name_mapping = {
    "Trinidad & Tobago": "Trinidad and Tobago",
    "Hong Kong S.A.R., China": "Hong Kong",
    "Taiwan Province of China": "Taiwan",
    "Czech Republic": "Czechia"
}

for year, data in datasets.items():

    data["Country"] = (
        data["Country"]
        .str.strip()
        .replace(country_name_mapping)
    )

# %%
score_columns = {
    2015: "Happiness Score",
    2016: "Happiness Score",
    2017: "Happiness Score",
    2018: "Happiness Score",
    2019: "Happiness Score"
}
# happy score of country the each year
country_columns = {
    2015: "Country",
    2016: "Country",
    2017: "Country",
    2018: "Country",
    2019: "Country"
} # happy country of the each year

# %%
score_columns
# Out:
# {2015: 'Happiness Score',
#  2016: 'Happiness Score',
#  2017: 'Happiness Score',
#  2018: 'Happiness Score',
#  2019: 'Happiness Score'}

# %%
country_columns
# Out:
# {2015: 'Country',
#  2016: 'Country',
#  2017: 'Country',
#  2018: 'Country',
#  2019: 'Country'}

# %%
top_bottom_results = {} # top 10 and bottom 10 happest country in each year

for year, data in datasets.items():

    country_col = country_columns[year]
    score_col = score_columns[year]

    # Top 10 happiest countries
    top_10 = data[[country_col, score_col]].sort_values(
        by=score_col,
        ascending=False
    ).head(10)

    # Bottom 10 countries
    bottom_10 = data[[country_col, score_col]].sort_values(
        by=score_col,
        ascending=True
    ).head(10)

    top_bottom_results[year] = {
        "Top 10": top_10,
        "Bottom 10": bottom_10
    }

    print("\n" + "="*50)
    print(f"YEAR: {year}")

    print("\nTOP 10 HAPPIEST COUNTRIES")
    print(top_10)

    print("\nBOTTOM 10 HAPPIEST COUNTRIES")
    print(bottom_10)
# Out:
# ...
# YEAR: 2015
#
# TOP 10 HAPPIEST COUNTRIES
#        Country  Happiness Score
# 0  Switzerland            7.587
# 1      Iceland            7.561
# 2      Denmark            7.527
# 3       Norway            7.522
# 4       Canada            7.427
# 5      Finland            7.406
# 6  Netherlands            7.378
# 7       Sweden            7.364
# 8  New Zealand            7.286
# 9    Australia            7.284
#
# BOTTOM 10 HAPPIEST COUNTRIES
#           Country  Happiness Score
# 157          Togo            2.839
# 156       Burundi            2.905
# 155         Syria            3.006
# 154         Benin            3.340
# 153        Rwanda            3.465
# 152   Afghanistan            3.575
# 151  Burkina Faso            3.587
# 150   Ivory Coast            3.655
# 149        Guinea            3.656
# 148          Chad            3.667
#
# ...
# YEAR: 2016
#
# TOP 10 HAPPIEST COUNTRIES
#        Country  Happiness Score
# 0      Denmark            7.526
# ...

# %% [markdown]
# # Top 10 happiest Country visualization

# %%
import matplotlib.pyplot as plt

for year, results in top_bottom_results.items():

    top_10 = results["Top 10"]

    country_col = country_columns[year]
    score_col = score_columns[year]

    plt.figure(figsize=(10, 6))

    plt.barh(
        top_10[country_col],
        top_10[score_col]
    )

    plt.xlabel("Happiness Score")
    plt.ylabel("Country")
    plt.title(f"Top 10 Happiest Countries - {year}")

    plt.gca().invert_yaxis()

    plt.show()
    # horizontial bar chart beacuse is  clear and easy to understand and all year it is given below

# %% [markdown]
# # Bottom 10 Happiest Countries visualization

# %%
for year, results in top_bottom_results.items():

    bottom_10 = results["Bottom 10"]

    country_col = country_columns[year]
    score_col = score_columns[year]

    plt.figure(figsize=(10, 6))

    plt.barh(
        bottom_10[country_col],
        bottom_10[score_col]
    )

    plt.xlabel("Happiness Score")
    plt.ylabel("Country")
    plt.title(f"Bottom 10 Happiness Countries - {year}")

    plt.gca().invert_yaxis()

    plt.show()
    # horizontial bar chart beacuse is  clear and easy to understand and all years of the bottom 10 country are appearing in the each charts

# %% [markdown]
# # Q3. Analyze GDP/Economy versus Happiness Score. Calculate correlation and explain the result.

# %%
gdp_columns = {
    2015: "GDP",
    2016: "GDP",
    2017: "GDP",
    2018: "GDP",
    2019: "GDP"
}

# %%
correlation_results = {}

for year, data in datasets.items():

    gdp_col = gdp_columns[year]
    score_col = score_columns[year]

    correlation = data[gdp_col].corr(data[score_col])

    correlation_results[year] = correlation

    print(f"{year} Correlation: {correlation:.3f}")
# Out:
# 2015 Correlation: 0.781
# 2016 Correlation: 0.790
# 2017 Correlation: 0.812
# 2018 Correlation: 0.802
# 2019 Correlation: 0.794

# %%
correlation_df = pd.DataFrame(
    correlation_results.items(),
    columns=["Year", "GDP_Happiness_Correlation"]
)

correlation_df
# Out:
#    Year  GDP_Happiness_Correlation
# 0  2015                   0.780966
# 1  2016                   0.790322
# 2  2017                   0.812469
# 3  2018                   0.802124
# 4  2019                   0.793883

# %%
import matplotlib.pyplot as plt

for year, data in datasets.items():

    gdp_col = gdp_columns[year]
    score_col = score_columns[year]

    plt.figure(figsize=(8, 5))

    plt.scatter(
        data[gdp_col],
        data[score_col]
    )

    plt.xlabel("GDP / Economy")
    plt.ylabel("Happiness Score")
    plt.title(f"GDP vs Happiness Score - {year}")

    plt.grid()

    plt.show()

# %% [markdown]
# # The correlation analysis between GDP/Economy and Happiness Score shows a strong positive relationship across all five years from 2015 to 2019. The correlation values range from approximately 0.78 to 0.81. This indicates that countries with higher GDP per capita generally tend to have higher Happiness Scores.
#
# # The strongest relationship was observed in 2017, with a correlation of 0.812, while the lowest correlation was observed in 2015, with a correlation of 0.781.
#
# # Overall, GDP/Economy appears to be an important factor associated with happiness. However, correlation does not imply causation, and other factors such as social support, health, freedom, generosity, and trust in government may also influence a country's Happiness Score

# %% [markdown]
# # Q4. Analyze Social Support versus Happiness Score. Determine whether higher social support tends to relate to higher happiness

# %%
datasets
# Out:
# {2015:          Country                           Region  Rank  Happiness Score  \
#  0    Switzerland                   Western Europe     1            7.587
#  1        Iceland                   Western Europe     2            7.561
#  2        Denmark                   Western Europe     3            7.527
#  3         Norway                   Western Europe     4            7.522
#  4         Canada                    North America     5            7.427
#  ..           ...                              ...   ...              ...
#  153       Rwanda               Sub-Saharan Africa   154            3.465
#  154        Benin               Sub-Saharan Africa   155            3.340
#  155        Syria  Middle East and Northern Africa   156            3.006
#  156      Burundi               Sub-Saharan Africa   157            2.905
#  157         Togo               Sub-Saharan Africa   158            2.839
#
#       Standard Error      GDP  Social Support  Life Expectancy  Freedom  \
# ...

# %%
social_support_columns[2015]
# Out:
# 'Social support'

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Social Support columns
social_support_columns = {
    2015: "Social Support",
    2016: "Social Support",
    2017: "Social Support",
    2018: "Social Support",
    2019: "Social Support"
}


# Happiness Score columns
score_columns = {
    2015: "Happiness Score",
    2016: "Happiness Score",
    2017: "Happiness Score",
    2018: "Happiness Score",
    2019: "Happiness Score"
}


# Dictionary to store correlations
social_happiness_correlation = {}


for year, data in datasets.items():

    social_col = social_support_columns[year]
    score_col = score_columns[year]

    # Calculate correlation
    correlation = data[social_col].corr(data[score_col])

    social_happiness_correlation[year] = correlation

    print(f"\nYear: {year}")
    print(f"Social Support vs Happiness Correlation: {correlation:.6f}")


    # Scatter Plot
    plt.figure(figsize=(8, 5))

    plt.scatter(
        data[social_col],
        data[score_col]
    )

    plt.xlabel("Social Support")
    plt.ylabel("Happiness Score")
    plt.title(f"Social Support vs Happiness Score - {year}")

    plt.grid()

    plt.show()


# Summary DataFrame
social_correlation_df = pd.DataFrame(
    list(social_happiness_correlation.items()),
    columns=["Year", "SocialSupport_Happiness_Correlation"]
)

print("\nCorrelation Summary:")
print(social_correlation_df)
# Out:
# Year: 2015
# Social Support vs Happiness Correlation: 0.740605
# Year: 2016
# Social Support vs Happiness Correlation: 0.739252
# Year: 2017
# Social Support vs Happiness Correlation: 0.752737
# Year: 2018
# Social Support vs Happiness Correlation: 0.745760
# Year: 2019
# Social Support vs Happiness Correlation: 0.777058
# Correlation Summary:
#    Year  SocialSupport_Happiness_Correlation
# 0  2015                             0.740605
# 1  2016                             0.739252
# 2  2017                             0.752737
# 3  2018                             0.745760
# 4  2019                             0.777058

# %% [markdown]
# # The correlation analysis between Social Support and Happiness Score was performed for each year from 2015 to 2019. A positive correlation would indicate that countries with higher social support generally tend to report higher Happiness Scores. The strength of the relationship can be determined from the calculated correlation values.

# %% [markdown]
# # Q5. Compare Happiness Score with healthy life expectancy. Create a scatter plot and interpret the relationship.

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Healthy Life Expectancy columns
life_expectancy_columns = {
    2015: "Life Expectancy",
    2016: "Life Expectancy",
    2017: "Life Expectancy",
    2018: "Life Expectancy",
    2019: "Life Expectancy"
}


# Happiness Score columns
score_columns = {
    2015: "Happiness Score",
    2016: "Happiness Score",
    2017: "Happiness Score",
    2018: "Happiness Score",
    2019: "Happiness Score"
}



# Store correlations
life_happiness_correlation = {}


for year, data in datasets.items():

    life_col = life_expectancy_columns[year]
    score_col = score_columns[year]

    # Calculate correlation
    correlation = data[life_col].corr(data[score_col])

    life_happiness_correlation[year] = correlation

    print(f"\nYear: {year}")
    print(f"Healthy Life Expectancy vs Happiness Correlation: {correlation:.6f}")


    # Scatter Plot
    plt.figure(figsize=(8, 5))

    plt.scatter(
        data[life_col],
        data[score_col]
    )

    plt.xlabel("Healthy Life Expectancy")
    plt.ylabel("Happiness Score")
    plt.title(f"Healthy Life Expectancy vs Happiness Score - {year}")

    plt.grid()

    plt.show()


# Correlation Summary Table
life_correlation_df = pd.DataFrame(
    list(life_happiness_correlation.items()),
    columns=["Year", "LifeExpectancy_Happiness_Correlation"]
)

print("\nCorrelation Summary:")
print(life_correlation_df)
# Out:
# Year: 2015
# Healthy Life Expectancy vs Happiness Correlation: 0.724200
# Year: 2016
# Healthy Life Expectancy vs Happiness Correlation: 0.765384
# Year: 2017
# Healthy Life Expectancy vs Happiness Correlation: 0.781951
# Year: 2018
# Healthy Life Expectancy vs Happiness Correlation: 0.775814
# Year: 2019
# Healthy Life Expectancy vs Happiness Correlation: 0.779883
# Correlation Summary:
#    Year  LifeExpectancy_Happiness_Correlation
# 0  2015                              0.724200
# 1  2016                              0.765384
# 2  2017                              0.781951
# 3  2018                              0.775814
# 4  2019                              0.779883

# %% [markdown]
# # The correlation analysis between Healthy Life Expectancy and Happiness Score shows a strong positive relationship across all five years from 2015 to 2019. The correlation values range from approximately 0.72 to 0.78.
#
# # This indicates that countries with higher healthy life expectancy generally tend to have higher Happiness Scores. The strongest relationship was observed in 2017, with a correlation of approximately 0.782, while the lowest correlation was observed in 2015, with a correlation of approximately 0.724.
#
# # The scatter plots would show an overall upward trend, indicating that as Healthy Life Expectancy increases, the Happiness Score generally increases.

# %% [markdown]
# # Q6. Analyze freedom to make life choices versus happiness. Identify high/high, high/low, low/high, and low/low examples.

# %%
freedom_columns = {
    2015: "Freedom",
    2016: "Freedom",
    2017: "Freedom",
    2018: "Freedom",
    2019: "Freedom"
}

# Happiness Score columns
score_columns = {
    2015: "Happiness Score",
    2016: "Happiness Score",
    2017: "Happiness Score",
    2018: "Happiness Score",
    2019: "Happiness Score"
}


country_columns = {
    2015: "Country",
    2016: "Country",
    2017: "Country",
    2018: "Country",
    2019: "Country"
}

# %%
freedom_happiness_correlation = {}

for year, data in datasets.items():

    freedom_col = freedom_columns[year]
    score_col = score_columns[year]

    correlation = data[freedom_col].corr(data[score_col])

    freedom_happiness_correlation[year] = correlation

    print(f"{year}: {correlation:.6f}") # correlation of the each year freedom score
# Out:
# 2015: 0.568211
# 2016: 0.566827
# 2017: 0.570137
# 2018: 0.544280
# 2019: 0.566742

# %%
import pandas as pd

quadrant_results = {}

for year, data in datasets.items():

    country_col = country_columns[year]
    freedom_col = freedom_columns[year]
    score_col = score_columns[year]

    # Create a new DataFrame
    df = data[[country_col, freedom_col, score_col]].copy()

    # Find median values
    freedom_median = df[freedom_col].median()
    happiness_median = df[score_col].median()
    # helps us categorize countries into High and Low groups for the four combinations
    # Categorize Freedom
    df["Freedom_Level"] = df[freedom_col].apply(
        lambda x: "High" if x >= freedom_median else "Low"
    )

    # Categorize Happiness
    df["Happiness_Level"] = df[score_col].apply(
        lambda x: "High" if x >= happiness_median else "Low"
    )

    # Combine the categories
    df["Category"] = (
        df["Freedom_Level"] + " Freedom / " +
        df["Happiness_Level"] + " Happiness"
    )

    quadrant_results[year] = df

    print("\n" + "=" * 60)
    print(f"YEAR: {year}")
    print("=" * 60)

    print(df["Category"].value_counts()) # total country flows on the each category
# Out:
# ...
# YEAR: 2015
# ...
# Category
# High Freedom / High Happiness    58
# Low Freedom / Low Happiness      58
# Low Freedom / High Happiness     21
# High Freedom / Low Happiness     21
# Name: count, dtype: int64
#
# ...
# YEAR: 2016
# ...
# Category
# High Freedom / High Happiness    53
# Low Freedom / Low Happiness      52
# Low Freedom / High Happiness     26
# High Freedom / Low Happiness     26
# Name: count, dtype: int64
#
# ...
# YEAR: 2017
# ...
# Category
# High Freedom / High Happiness    53
# Low Freedom / Low Happiness      52
# Low Freedom / High Happiness     25
# High Freedom / Low Happiness     25
# Name: count, dtype: int64
#
# ...
# YEAR: 2018
# ...
# Category
# High Freedom / High Happiness    53
# Low Freedom / Low Happiness      53
# Low Freedom / High Happiness     25
# High Freedom / Low Happiness     25
# Name: count, dtype: int64
#
# ...
# YEAR: 2019
# ...
# Category
# High Freedom / High Happiness    56
# Low Freedom / Low Happiness      55
# High Freedom / Low Happiness     23
# Low Freedom / High Happiness     22
# ...

# %%
for year, df in quadrant_results.items(): # which countrys are flows on the each category

    print("\n" + "=" * 70)
    print(f"YEAR {year}")
    print("=" * 70)

    for category in df["Category"].unique():

        print(f"\n{category}")

        print(
            df[df["Category"] == category]
            .head(5)
        )
# Out:
# ...
# YEAR 2015
# ...
#
# High Freedom / High Happiness
#        Country  Freedom  Happiness Score Freedom_Level Happiness_Level  \
# 0  Switzerland  0.66557            7.587          High            High
# 1      Iceland  0.62877            7.561          High            High
# 2      Denmark  0.64938            7.527          High            High
# 3       Norway  0.66973            7.522          High            High
# 4       Canada  0.63297            7.427          High            High
#
#                         Category
# 0  High Freedom / High Happiness
# 1  High Freedom / High Happiness
# 2  High Freedom / High Happiness
# 3  High Freedom / High Happiness
# 4  High Freedom / High Happiness
#
# Low Freedom / High Happiness
#          Country  Freedom  Happiness Score Freedom_Level Happiness_Level  \
# 10        Israel  0.41319            7.278           Low            High
# 22     Venezuela  0.42908            6.810           Low            High
# ...

# %%
for year, df in quadrant_results.items(): # score of each country that flows on the each categories

    country_col = country_columns[year]
    freedom_col = freedom_columns[year]
    score_col = score_columns[year]

    print("\n" + "=" * 70)
    print(f"YEAR {year}")
    print("=" * 70)

    categories = [
        "High Freedom / High Happiness",
        "High Freedom / Low Happiness",
        "Low Freedom / High Happiness",
        "Low Freedom / Low Happiness"
    ]

    for category in categories:

        print(f"\n{category}")

        result = df[df["Category"] == category][
            [country_col, freedom_col, score_col]
        ].head(5)

        print(result)
# Out:
# ...
# YEAR 2015
# ...
#
# High Freedom / High Happiness
#        Country  Freedom  Happiness Score
# 0  Switzerland  0.66557            7.587
# 1      Iceland  0.62877            7.561
# 2      Denmark  0.64938            7.527
# 3       Norway  0.66973            7.522
# 4       Canada  0.63297            7.427
#
# High Freedom / Low Happiness
#               Country  Freedom  Happiness Score
# 83              China  0.51697            5.140
# 84             Zambia  0.48827            5.129
# 87           Portugal  0.51469            5.102
# 89        Philippines  0.62545            5.073
# 90  Somaliland region  0.46582            5.057
#
# Low Freedom / High Happiness
#          Country  Freedom  Happiness Score
# 10        Israel  0.41319            7.278
# 22     Venezuela  0.42908            6.810
# 34  Saudi Arabia  0.31048            6.411
# 37        Taiwan  0.39740            6.298
# 41   El Salvador  0.40350            6.130
#
# Low Freedom / Low Happiness
# ...

# %%
import matplotlib.pyplot as plt

for year, data in datasets.items():

    freedom_col = freedom_columns[year]
    score_col = score_columns[year]

    plt.figure(figsize=(8, 6))

    plt.scatter(
        data[freedom_col],
        data[score_col]
    )

    # Median dividing lines
    plt.axvline(
        data[freedom_col].median(),
        linestyle="--"
    )

    plt.axhline(
        data[score_col].median(),
        linestyle="--"
    )

    plt.xlabel("Freedom to Make Life Choices")
    plt.ylabel("Happiness Score")
    plt.title(f"Freedom vs Happiness Score - {year}")

    plt.grid()

    plt.show()

# %% [markdown]
# # The relationship between Freedom to Make Life Choices and Happiness Score was analyzed by dividing countries into four categories using the median values of Freedom and Happiness Score. Countries were classified as High Freedom/High Happiness, High Freedom/Low Happiness, Low Freedom/High Happiness, and Low Freedom/Low Happiness. This analysis helps identify whether greater freedom generally tends to be associated with higher happiness while also highlighting exceptions where other factors influence happiness.

# %% [markdown]
# # The analysis of Freedom to Make Life Choices and Happiness Score shows that freedom generally has a positive relationship with happiness. Countries with high freedom and high happiness support the idea that having greater control over life decisions is associated with better well-being.
#
# # However, the presence of high freedom/low happiness and low freedom/high happiness countries shows that freedom alone does not determine happiness. Other factors such as GDP, social support, healthy life expectancy, and government conditions also influence overall happiness.
#
# # Overall, greater freedom tends to be associated with higher happiness, but happiness is influenced by multiple social, economic, and health-related factors.

# %% [markdown]
# # Freedom to make life choices generally contributes positively to happiness, but it is not the only factor determining a country's overall well-being.

# %% [markdown]
# # Q7. Group countries by region and calculate average, maximum, and minimum happiness scores. Identify highest- and lowest-performing regions.

# %%
dataset16.columns
# Out:
# Index(['Country', 'Region', 'Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval', 'GDP',
#        'Social Support', 'Life Expectancy', 'Freedom', 'Corruption Perception',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
region_columns = {
    2015: "Region",
    2016: "Region"
}

score_columns = {
    2015: "Happiness Score",
    2016: "Happiness Score"
}

# %%
region_results = {}

for year in [2015, 2016]:

    data = datasets[year]

    region_col = region_columns[year]
    score_col = score_columns[year]

    region_summary = data.groupby(region_col)[score_col].agg(
        Average="mean",
        Maximum="max",
        Minimum="min"
    ).round(3)

    # Sort based on average happiness
    region_summary = region_summary.sort_values(
        by="Average",
        ascending=False
    )

    region_results[year] = region_summary

    print("\n" + "=" * 60)
    print(f"REGION HAPPINESS ANALYSIS - {year}")
    print("=" * 60)

    print(region_summary)
# Out:
# ...
# REGION HAPPINESS ANALYSIS - 2015
# ...
#                                  Average  Maximum  Minimum
# Region
# Australia and New Zealand          7.285    7.286    7.284
# North America                      7.273    7.427    7.119
# Western Europe                     6.690    7.587    4.857
# Latin America and Caribbean        6.145    7.226    4.518
# Eastern Asia                       5.626    6.298    4.874
# Middle East and Northern Africa    5.407    7.278    3.006
# Central and Eastern Europe         5.333    6.505    4.218
# Southeastern Asia                  5.317    6.798    3.819
# Southern Asia                      4.581    5.253    3.575
# Sub-Saharan Africa                 4.203    5.477    2.839
#
# ...
# REGION HAPPINESS ANALYSIS - 2016
# ...
#                                  Average  Maximum  Minimum
# Region
# Australia and New Zealand          7.323    7.334    7.313
# North America                      7.254    7.404    7.104
# ...

# %%
region_results = {}

for year in [2015, 2016]:

    data = datasets[year]

    region_col = region_columns[year]
    score_col = score_columns[year]

    region_summary = data.groupby(region_col)[score_col].agg(
        Average="mean",
        Maximum="max",
        Minimum="min"
    ).round(3)

    # Sort based on average happiness
    region_summary = region_summary.sort_values(
        by="Average",
        ascending=False
    )

    region_results[year] = region_summary

    print("\n" + "=" * 60)
    print(f"REGION HAPPINESS ANALYSIS - {year}")
    print("=" * 60)

    print(region_summary)
# Out:
# ...
# REGION HAPPINESS ANALYSIS - 2015
# ...
#                                  Average  Maximum  Minimum
# Region
# Australia and New Zealand          7.285    7.286    7.284
# North America                      7.273    7.427    7.119
# Western Europe                     6.690    7.587    4.857
# Latin America and Caribbean        6.145    7.226    4.518
# Eastern Asia                       5.626    6.298    4.874
# Middle East and Northern Africa    5.407    7.278    3.006
# Central and Eastern Europe         5.333    6.505    4.218
# Southeastern Asia                  5.317    6.798    3.819
# Southern Asia                      4.581    5.253    3.575
# Sub-Saharan Africa                 4.203    5.477    2.839
#
# ...
# REGION HAPPINESS ANALYSIS - 2016
# ...
#                                  Average  Maximum  Minimum
# Region
# Australia and New Zealand          7.323    7.334    7.313
# North America                      7.254    7.404    7.104
# ...

# %%
for year, summary in region_results.items():

    highest_region = summary["Average"].idxmax()
    highest_score = summary["Average"].max()

    lowest_region = summary["Average"].idxmin()
    lowest_score = summary["Average"].min()

    print(f"\nYEAR: {year}")

    print(
        f"Highest Performing Region: "
        f"{highest_region} ({highest_score:.3f})"
    )

    print(
        f"Lowest Performing Region: "
        f"{lowest_region} ({lowest_score:.3f})"
    )
# Out:
# YEAR: 2015
# Highest Performing Region: Australia and New Zealand (7.285)
# Lowest Performing Region: Sub-Saharan Africa (4.203)
#
# YEAR: 2016
# Highest Performing Region: Australia and New Zealand (7.323)
# Lowest Performing Region: Sub-Saharan Africa (4.136)

# %%
import matplotlib.pyplot as plt

for year, summary in region_results.items():

    plt.figure(figsize=(10, 6))

    plt.barh(
        summary.index,
        summary["Average"]
    )

    plt.xlabel("Average Happiness Score")
    plt.ylabel("Region")
    plt.title(f"Average Happiness Score by Region - {year}")

    plt.gca().invert_yaxis()

    plt.show()

# %% [markdown]
# # Countries were grouped according to their geographical regions, and the average, maximum, and minimum Happiness Scores were calculated for each region. The regions were compared based on their average Happiness Score. The region with the highest average score was identified as the highest-performing region, while the region with the lowest average score was identified as the lowest-performing region.

# %% [markdown]
# # The regional analysis of Happiness Scores for 2015 and 2016 shows that Australia and New Zealand was the highest-performing region in both years based on the average Happiness Score.
#
# #In 2015, Australia and New Zealand had an average Happiness Score of 7.285, which increased slightly to 7.323 in 2016.
#
# # On the other hand, Sub-Saharan Africa was the lowest-performing region in both years. Its average Happiness Score was 4.203 in 2015 and decreased to 4.136 in 2016.
#
# # Overall, the results show a clear regional difference in happiness levels. Australia and New Zealand consistently performed the best, while Sub-Saharan Africa consistently had the lowest average Happiness Scores during the analyzed period.

# %% [markdown]
# # Q8. Compare happiness scores across years and identify countries where happiness increased, decreased, or remained stable.

# %%
import pandas as pd

# Country column names
country_columns = {
    2015: "Country",
    2016: "Country",
    2017: "Country",
    2018: "Country",
    2019: "Country"
}


# Happiness Score column names
score_columns = {
    2015: "Happiness Score",
    2016: "Happiness Score",
    2017: "Happiness Score",
    2018: "Happiness Score",
    2019: "Happiness Score"
}


# Store yearly data
happiness_data = []


# Extract required columns
for year, data in datasets.items():

    country_col = country_columns[year]
    score_col = score_columns[year]

    temp = data[[country_col, score_col]].copy()

    # Standardize column names
    temp.columns = ["Country", "Happiness Score"]

    # Add Year
    temp["Year"] = year

    happiness_data.append(temp)


# Combine all datasets
combined_happiness = pd.concat(
    happiness_data,
    ignore_index=True
)


# Create country vs year table
happiness_pivot = combined_happiness.pivot(
    index="Country",
    columns="Year",
    values="Happiness Score"
)


# Calculate change from first available year to last available year
def calculate_change(row):

    values = row.dropna()

    if len(values) < 2:
        return None

    return values.iloc[-1] - values.iloc[0]


happiness_pivot["Change"] = happiness_pivot.apply(
    calculate_change,
    axis=1
)


# Classify change
def classify_change(change):

    if pd.isna(change):
        return "Insufficient Data"

    elif change > 0.05:
        return "Increased"

    elif change < -0.05:
        return "Decreased"

    else:
        return "Stable"


happiness_pivot["Status"] = happiness_pivot["Change"].apply(
    classify_change
)


# Results
print("\nCOUNTRIES WITH INCREASED HAPPINESS")
print(
    happiness_pivot[
        happiness_pivot["Status"] == "Increased"
    ]
)


print("\nCOUNTRIES WITH DECREASED HAPPINESS")
print(
    happiness_pivot[
        happiness_pivot["Status"] == "Decreased"
    ]
)


print("\nCOUNTRIES WITH STABLE HAPPINESS")
print(
    happiness_pivot[
        happiness_pivot["Status"] == "Stable"
    ]
)


# Summary
print("\nSUMMARY")
print(happiness_pivot["Status"].value_counts())
# Out:
# COUNTRIES WITH INCREASED HAPPINESS
# Year                     2015   2016   2017   2018   2019  Change     Status
# Country
# Armenia                 4.350  4.360  4.376  4.321  4.559   0.209  Increased
# Bahrain                 5.960  6.218  6.087  6.105  6.199   0.239  Increased
# Benin                   3.340  3.484  3.657  4.141  4.883   1.543  Increased
# Bosnia and Herzegovina  4.949  5.163  5.182  5.129  5.386   0.437  Increased
# Bulgaria                4.218  4.217  4.714  4.933  5.011   0.793  Increased
# ...                       ...    ...    ...    ...    ...     ...        ...
# Tajikistan              4.786  4.996  5.041  5.199  5.467   0.681  Increased
# Togo                    2.839  3.303  3.495  3.999  4.085   1.246  Increased
# Uganda                  3.931  3.739  4.081  4.161  4.189   0.258  Increased
# United Kingdom          6.867  6.725  6.714  7.190  7.054   0.187  Increased
# Uzbekistan              6.003  5.987  5.971  6.096  6.174   0.171  Increased
#
# ...

# %% [markdown]
# # The comparison of Happiness Scores from 2015 to 2019 shows that happiness levels changed differently across countries. Out of the countries analyzed, 73 countries showed an increase in happiness, while 67 countries experienced a decrease, and 21 countries remained relatively stable.
#
# # Overall, slightly more countries experienced an improvement in Happiness Scores than a decline. However, the results also show that happiness is not uniform across countries, with some countries experiencing major improvements and others showing significant decreases.
#
# # Countries such as Benin and Togo showed notable improvements, while Venezuela, Zambia, and Zimbabwe experienced substantial declines. Countries such as New Zealand, Norway, France, and Sweden maintained relatively stable happiness levels.
#
# # Therefore, the analysis demonstrates that national happiness levels can change over time and are likely influenced by multiple economic, social, health, and political factors.

# %%
import matplotlib.pyplot as plt

countries = ["India", "Denmark", "Finland", "United States"]

for country in countries:

    if country in happiness_pivot.index:

        plt.plot(
            happiness_pivot.columns[:5],
            happiness_pivot.loc[country].iloc[:5],
            marker="o",
            label=country
        )


plt.xlabel("Year")
plt.ylabel("Happiness Score")
plt.title("Happiness Score Trends Across Years")

plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# # The Happiness Scores of countries were compared across the years 2015 to 2019. The change in Happiness Score was calculated by comparing the first available score with the last available score for each country. Countries were classified as having increased, decreased, or stable happiness levels using a small threshold to avoid treating minor score fluctuations as major changes.
#
# # This analysis helps identify long-term trends in happiness across countries and highlights which countries experienced improvement or decline during the study period.

# %% [markdown]
# # Q9. Determine which factors have the strongest relationship with happiness: GDP/Economy, Social Support, Life Expectancy, Freedom, Generosity, and Corruption Perception.

# %%
import pandas as pd

factors = [
    "GDP",
    "Social Support",
    "Life Expectancy",
    "Freedom",
    "Generosity",
    "Corruption Perception"
]

all_correlations = {}

for year, data in datasets.items():

    correlations = data[
        factors + ["Happiness Score"]
    ].corr()["Happiness Score"]

    all_correlations[year] = correlations[factors]


# Create correlation DataFrame
correlation_df = pd.DataFrame(all_correlations).T

print("YEAR-WISE CORRELATION")
print(correlation_df)


# Average correlation
average_correlation = correlation_df.mean()


# Create ranking
factor_ranking = pd.DataFrame({
    "Factor": average_correlation.index,
    "Average Correlation": average_correlation.values
})


# Absolute correlation
factor_ranking["Absolute Correlation"] = (
    factor_ranking["Average Correlation"].abs()
)


# Sort from strongest to weakest
factor_ranking = factor_ranking.sort_values(
    by="Absolute Correlation",
    ascending=False
).reset_index(drop=True)

factor_ranking
# Out:
# YEAR-WISE CORRELATION
#            GDP  Social Support  Life Expectancy   Freedom  Generosity  \
# 2015  0.780966        0.740605         0.724200  0.568211    0.180319
# 2016  0.790322        0.739252         0.765384  0.566827    0.156848
# 2017  0.812469        0.752737         0.781951  0.570137    0.155256
# 2018  0.802124        0.745760         0.775814  0.544280    0.135825
# 2019  0.793883        0.777058         0.779883  0.566742    0.075824
#
#       Corruption Perception
# 2015               0.395199
# 2016               0.402032
# 2017               0.429080
# 2018               0.400596
# 2019               0.385613
#                   Factor  Average Correlation  Absolute Correlation
# 0                    GDP             0.795953              0.795953
# 1        Life Expectancy             0.765446              0.765446
# 2         Social Support             0.751082              0.751082
# 3                Freedom             0.563239              0.563239
# ...

# %%
plt.figure(figsize=(10, 6))

plt.barh(
    factor_ranking["Factor"],
    factor_ranking["Average Correlation"]
)

plt.xlabel("Average Correlation with Happiness Score")
plt.ylabel("Factors")

plt.title("Factors Related to Happiness Score (2015–2019)")

plt.gca().invert_yaxis()

plt.show()

# %%
factor_ranking["Absolute Correlation"] = (
    factor_ranking["Average Correlation"].abs()
)

factor_ranking = factor_ranking.sort_values(
    by="Absolute Correlation",
    ascending=False
)

factor_ranking
# Out:
#                   Factor  Average Correlation  Absolute Correlation
# 0                    GDP             0.795953              0.795953
# 1        Life Expectancy             0.765446              0.765446
# 2         Social Support             0.751082              0.751082
# 3                Freedom             0.563239              0.563239
# 4  Corruption Perception             0.402504              0.402504
# 5             Generosity             0.140814              0.140814

# %% [markdown]
# #The correlation analysis shows that GDP/Economy has the strongest relationship with Happiness Score, with an average correlation of approximately 0.796. This is followed by Healthy Life Expectancy (0.765) and Social Support (0.751), which also show strong positive relationships with happiness.
#
# # Freedom to make life choices (0.563) has a moderate positive relationship with happiness. Corruption Perception (0.403) shows a weaker to moderate relationship, while Generosity (0.141) has the weakest relationship among the factors analyzed.
#
# # Overall, the results suggest that economic conditions, health, and social support are the three factors most strongly associated with Happiness Score in the datasets from 2015 to 2019.

# %% [markdown]
# # Q10. Provide 5 evidence-based recommendations that governments could consider to improve overall well-being

# %% [markdown]
# # 1.Strengthen Economic Development and Financial Security
# **Evidence:** GDP/Economy had the strongest relationship with Happiness Score (correlation = 0.796).
#
# **Recommendation:**
#
# Governments could:
#
# Create more employment opportunities
# Reduce poverty
# Support small and medium businesses
# Improve income security
# Reduce economic inequality
#
# Improving economic conditions may contribute significantly to overall well-being.

# %% [markdown]
# # 2. Invest in Healthcare and Healthy Life Expectancy.
# **Evidence:** Healthy Life Expectancy had the second strongest relationship with happiness (correlation = 0.765).
#
# **Recommendation:**
#
# Governments could:
#
# Improve access to healthcare
# Invest in preventive healthcare
# Promote healthy lifestyles
# Improve healthcare infrastructure
#
# Better health and longer healthy lives are strongly associated with higher happiness.

# %% [markdown]
# # 3. Strengthen Social Support Systems
# **Evidence:** Social Support had a strong positive relationship with Happiness Score (correlation = 0.751).
#
# **Recommendation:**
#
# Governments could:
#
# Strengthen social security programs
# Support vulnerable populations
# Develop community support programs
# Improve access to social services
#
# Strong social support systems can help improve people's security and overall well-being.

# %% [markdown]
# # 4.Promote Freedom to Make Life Choices
# **Evidence:** Freedom showed a moderate positive relationship with happiness (correlation = 0.563).
#
# **Recommendation:**
#
# Governments could promote:
#
# Equal access to education
# Employment opportunities
# Personal and career choices
# Participation in social and public life
#
# Greater freedom and personal choice are associated with higher levels of happiness.

# %% [markdown]
# # 5. Improve Government Transparency and Reduce Corruption.
# **Evidence:** Corruption Perception showed a positive relationship with Happiness Score (correlation = 0.403).
#
# **Recommendation:**
#
# Governments could:
#
# Improve transparency
# Strengthen accountability
# Reduce corruption
# Improve public service delivery
# Build public trust
#
# Trust in institutions can contribute to improved social well-being.

# %% [markdown]
# # Based on the correlation analysis of the World Happiness datasets from 2015 to 2019, governments should prioritize policies that improve economic conditions, healthcare, and social support, as these factors showed the strongest relationships with Happiness Score. Governments should also promote individual freedom and transparent governance to support overall well-being.
#
# #The analysis suggests that improving happiness requires a multi-dimensional approach. Economic growth alone is not sufficient; governments should also focus on health, social relationships, personal freedom, and effective institutions.
